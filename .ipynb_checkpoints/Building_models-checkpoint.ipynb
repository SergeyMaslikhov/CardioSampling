# %%
import pandas as pd
import numpy as np
from itertools import cycle
import pickle

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import scipy.stats as st

from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
# from sklearn.svm import SVR

from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from hyperopt import hp, tpe, space_eval
from hyperopt.fmin import fmin

from xgboost import plot_importance
import os

# %%
def hyperopt_model(model, params, X, y, evals=30):
    def hyperopt_score(params):
        clf = model(**params)
        return -cross_val_score(clf, X, y, scoring='neg_root_mean_squared_error', cv=5).mean()

    best = fmin(fn=hyperopt_score, space=params, algo=tpe.suggest, max_evals=evals)
    return model(**space_eval(params, best))

# %%
# space_svm = {
#       'C': hp.choice('C', np.arange(0.5,20, 0.5)),
#       'kernel': hp.choice('kernel',['rbf']),
#       'degree':hp.choice('degree',[2,3,4])      }

xgboost_space={
            'max_depth': hp.choice('x_max_depth',[2,3,4,5,6]),
            'min_child_weight':hp.choice('x_min_child_weight',np.round(np.arange(0.0,0.2,0.01),5)),
            'learning_rate':hp.choice('x_learning_rate',np.round(np.arange(0.005,0.3,0.01),5)),
            'subsample':hp.choice('x_subsample',np.round(np.arange(0.1,1.0,0.05),5)),
            'colsample_bylevel':hp.choice('x_colsample_bylevel',np.round(np.arange(0.1,1.0,0.05),5)),
            'colsample_bytree':hp.choice('x_colsample_bytree',np.round(np.arange(0.1,1.0,0.05),5)),
            'n_estimators':hp.choice('x_n_estimators',np.arange(100, 300, 50))
}

space4rf = {
    'max_depth': hp.choice('max_depth', range(1,20)),
    'max_features': hp.choice('max_features', ['sqrt', 'log2']),
    'n_estimators': hp.choice('n_estimators', range(100,1000, 100)),
}

# %%
def model_boundaries(model, X_train, y_train, scoring, cv=5):
    ''' вычисление дов. ин-ла по n фолдам кросс-валидации'''
    # вычисляем score на кросс валидации
    val_scores = -cross_val_score(model, X_train, y_train, cv=5, scoring=scoring)
    # доверительный интервал
    conf_interval = st.t.interval(0.95, len(val_scores)-1, loc=val_scores.mean(), scale=val_scores.std())
    return conf_interval

# %% [markdown]
# *Пайплайн построения и оценки моделей*
# * Считывание датасета, выделение таргета и нужных колонок
# * Отбор топ 6 по корреляции
# * Разделение на обучение и тест
# * Подбор гиперпараметров по кросс валидации, их доверительные интервалы
# * Обучение, тестирование, отображение R2, RMSE, сетку ошибок кларка, важность фичей

# %%
def build_asses_model(file, model, model_space, model_nm='xgb', evals=50):
    print(file.upper())
    df = pd.read_csv(f'datasets\\{file}')
    df = df.dropna(subset=df.iloc[:, 6:].columns)
    y = df['Уровень глюкозы, ммоль/л']
    print(f'Target STD: {y.std():.3f}')
    # отбор признаков
    df = df.iloc[:, 6:]
    selector = SelectKBest(f_regression, k=10)
    X_corr = selector.fit_transform(df, y)
    feature_names = list(df.columns[selector.get_support()])
    plt.figure(figsize=(5, 3))
    sns.heatmap(df.loc[:, feature_names].corrwith(y).to_numpy().reshape(-1, 1), annot=True, yticklabels=feature_names)

    # обучение и тестирование
    X_train, X_test, y_train, y_test = train_test_split(X_corr, y, test_size=0.25, random_state=0)
    print(f'Размер обучающей выборки: {len(X_train)}\nРазмер тестовой выборки: {len(X_test)}')
    model = hyperopt_model(model, model_space, X_train, y_train, evals=evals)
    lower, upper = model_boundaries(model, X_train, y_train, scoring="neg_root_mean_squared_error")
    print(f'95% доверительный интервал модели для RMSE по кросс валидации: ({lower:.3f}, {upper:.3f})')
    model.fit(X_train, y_train)
    if 'XGB' in str(model):
        model.get_booster().feature_names = feature_names
        ax = plot_importance(model.get_booster())
        fig = ax.figure
        fig.set_size_inches(4, 3)
    elif 'Random' in str(model):
        fig, ax = plt.subplots(figsize=(4, 3))
        importances = model.feature_importances_
        forest_importances = pd.Series(importances, index=feature_names)
        forest_importances.plot.bar(ax=ax)
        ax.set_title("Feature importances using MDI")
        ax.set_ylabel("Mean decrease in impurity")
        fig.tight_layout()
    preds = model.predict(X_test)
    print(f'R2 test: {r2_score(y_test, preds):.3f}, RMSE test: {mean_squared_error(y_test, preds)**0.5:.3f}')
    plt.figure(figsize=(10, 6))
    abs_zone, rel_zone = clarke_error_grid(y_test.to_numpy()*18.02, preds*18.02, 'Error GRid')
    pd.DataFrame.from_dict({'A':[f'{abs_zone[0]}({rel_zone[0]}%)'], 'B':[f'{abs_zone[1]}({rel_zone[1]}%)'], 
                  'C':[f'{abs_zone[2]}({rel_zone[2]}%)'], 'D':[f'{abs_zone[3]}({rel_zone[3]}%)'],
                           'E':[f'{abs_zone[4]}({rel_zone[4]}%)']}).to_excel(f'results/{file[:-4]}_{model_nm}.xlsx', index=False)
    print(f'Clarke Error Grid: A - {abs_zone[0]}({rel_zone[0]}%), B - {abs_zone[1]}({rel_zone[1]}%), C - {abs_zone[2]}({rel_zone[2]}%), D - {abs_zone[3]}({rel_zone[3]}%), E - {abs_zone[4]}({rel_zone[4]}%)', end='\n\n')

# %% [markdown]
# ## Вся выборка

# %%
pd.read_csv('datasets/all.csv').columns
# Out:
# Index(['Unnamed: 0', 'Уровень глюкозы, ммоль/л', 'Возраст, лет', 'Вес, кг',
#        'Рост, см', 'Пол', 'AR_PPG_1', 'AR_PPG_2', 'AR_PPG_3', 'AR_PPG_4',
#        'AR_PPG_5', 'AR_KTE_1', 'AR_KTE_2', 'AR_KTE_3', 'AR_KTE_4', 'AR_KTE_5',
#        'KTE_mean', 'KTE_std', 'KTE_skew', 'KTE_iqr', 'entropy_mean',
#        'entropy_std', 'entropy_skew', 'entropy_iqr', 'AR_spectral_energy_1',
#        'AR_spectral_energy_2', 'AR_spectral_energy_3', 'AR_spectral_energy_4',
#        'AR_spectral_energy_5', 'spectral_energy_mean', 'spectral_energy_std',
#        'spectral_energy_skew', 'spectral_energy_iqr', 'bpm_ppg', 'ibi_ppg',
#        'sdnn_ppg', 'sdsd_ppg', 'rmssd_ppg', 'pnn20_ppg', 'pnn50_ppg',
#        'hr_mad_ppg', 'sd1_ppg', 'sd2_ppg', 's_ppg', 'sd1/sd2_ppg',
#        'breathingrate_ppg', 'vlf_ppg', 'lf_ppg', 'hf_ppg', 'lf/hf_ppg',
#        'p_total_ppg', 'vlf_perc_ppg', 'lf_perc_ppg', 'hf_perc_ppg',
#        'lf_nu_ppg', 'hf_nu_ppg'],
#       dtype='object')

# %%
build_asses_model('all.csv', XGBRegressor, xgboost_space)
# Out:
# ALL.CSV
# Target STD: 3.400
# Размер обучающей выборки: 2060
# Размер тестовой выборки: 687
# 100%|████████████████████████████████████████████████| 50/50 [00:21<00:00,  2.29trial/s, best loss: 3.1690573716270443]
# 95% доверительный интервал модели для RMSE по кросс валидации: (2.726, 3.612)
# R2 test: 0.132, RMSE test: 3.183
# Clarke Error Grid: A - 251(36.54%), B - 375(54.59%), C - 1(0.15%), D - 59(8.59%), E - 1(0.15%)

# %%
build_asses_model('all.csv', RandomForestRegressor, space4rf, model_nm='rf', evals=20)
# Out:
# ALL.CSV
# Target STD: 3.400
# Размер обучающей выборки: 2060
# Размер тестовой выборки: 687
# 100%|████████████████████████████████████████████████| 20/20 [04:17<00:00, 12.88s/trial, best loss: 3.1721782644224215]
# 95% доверительный интервал модели для RMSE по кросс валидации: (2.726, 3.629)
# R2 test: 0.135, RMSE test: 3.179
# Clarke Error Grid: A - 254(36.97%), B - 372(54.15%), C - 0(0.0%), D - 61(8.88%), E - 0(0.0%)

# %% [markdown]
# ## Выборка женщин

# %%
build_asses_model('women.csv', XGBRegressor, xgboost_space)
# Out:
# WOMEN.CSV
# Target STD: 3.372
# Размер обучающей выборки: 1386
# Размер тестовой выборки: 462
# 100%|██████████████████████████████████████████████████| 50/50 [00:16<00:00,  3.07trial/s, best loss: 3.06483058724102]
# 95% доверительный интервал модели для RMSE по кросс валидации: (2.938, 3.192)
# R2 test: 0.167, RMSE test: 3.071
# Clarke Error Grid: A - 208(45.02%), B - 215(46.54%), C - 0(0.0%), D - 39(8.44%), E - 0(0.0%)

# %%
build_asses_model('women.csv', RandomForestRegressor, space4rf, model_nm='rf', evals=20)
# Out:
# WOMEN.CSV
# Target STD: 3.372
# Размер обучающей выборки: 1386
# Размер тестовой выборки: 462
# 100%|████████████████████████████████████████████████| 20/20 [02:51<00:00,  8.56s/trial, best loss: 3.0823299498841075]
# 95% доверительный интервал модели для RMSE по кросс валидации: (2.901, 3.260)
# R2 test: 0.162, RMSE test: 3.081
# Clarke Error Grid: A - 201(43.51%), B - 220(47.62%), C - 0(0.0%), D - 41(8.87%), E - 0(0.0%)

# %% [markdown]
# ## Выборка мужчин

# %%
build_asses_model('men.csv', XGBRegressor, xgboost_space)
# Out:
# MEN.CSV
# Target STD: 3.332
# Размер обучающей выборки: 674
# Размер тестовой выборки: 225
# 100%|█████████████████████████████████████████████████| 50/50 [00:15<00:00,  3.24trial/s, best loss: 3.182563959499067]
# 95% доверительный интервал модели для RMSE по кросс валидации: (2.867, 3.498)
# R2 test: 0.008, RMSE test: 3.418
# Clarke Error Grid: A - 89(39.56%), B - 115(51.11%), C - 1(0.44%), D - 20(8.89%), E - 0(0.0%)

# %%
build_asses_model('men.csv', RandomForestRegressor, space4rf, model_nm='rf', evals=20)
# Out:
# MEN.CSV
# Target STD: 3.332
# Размер обучающей выборки: 674
# Размер тестовой выборки: 225
# 100%|█████████████████████████████████████████████████| 20/20 [01:36<00:00,  4.80s/trial, best loss: 3.160409891157942]
# 95% доверительный интервал модели для RMSE по кросс валидации: (2.876, 3.477)
# R2 test: 0.025, RMSE test: 3.387
# Clarke Error Grid: A - 87(38.67%), B - 114(50.67%), C - 2(0.89%), D - 22(9.78%), E - 0(0.0%)

# %% [markdown]
# ## Выборка людей с диабетом

# %%
pd.read_csv('datasets/diabetes.csv')['Пол'].value_counts()
# Out:
# 2    1167
# 1     800
# Name: Пол, dtype: int64

# %%
build_asses_model('diabetes.csv', XGBRegressor, xgboost_space)
# Out:
# DIABETES.CSV
# Target STD: 3.291
# Размер обучающей выборки: 1475
# Размер тестовой выборки: 492
# 100%|████████████████████████████████████████████████| 50/50 [00:18<00:00,  2.77trial/s, best loss: 3.2690809132853085]
# 95% доверительный интервал модели для RMSE по кросс валидации: (2.912, 3.626)
# R2 test: 0.046, RMSE test: 3.178
# Clarke Error Grid: A - 204(41.46%), B - 248(50.41%), C - 0(0.0%), D - 40(8.13%), E - 0(0.0%)

# %%
build_asses_model('diabetes.csv', RandomForestRegressor, space4rf, model_nm='rf', evals=20)
# Out:
# DIABETES.CSV
# Target STD: 3.291
# Размер обучающей выборки: 1475
# Размер тестовой выборки: 492
# 100%|████████████████████████████████████████████████| 20/20 [02:31<00:00,  7.58s/trial, best loss: 3.2600166639612547]
# 95% доверительный интервал модели для RMSE по кросс валидации: (2.922, 3.600)
# R2 test: 0.039, RMSE test: 3.190
# Clarke Error Grid: A - 208(42.28%), B - 238(48.37%), C - 1(0.2%), D - 45(9.15%), E - 0(0.0%)

# %% [markdown]
# ## Выборка людей без диабета

# %%
build_asses_model('nodiabetes.csv', XGBRegressor, xgboost_space)
# Out:
# NODIABETES.CSV
# Target STD: 0.807
# Размер обучающей выборки: 585
# Размер тестовой выборки: 195
# 100%|████████████████████████████████████████████████| 50/50 [00:11<00:00,  4.29trial/s, best loss: 0.7982744516300407]
# 95% доверительный интервал модели для RMSE по кросс валидации: (0.696, 0.901)
# R2 test: -0.085, RMSE test: 0.840
# Clarke Error Grid: A - 153(78.46%), B - 40(20.51%), C - 0(0.0%), D - 2(1.03%), E - 0(0.0%)

# %%
build_asses_model('nodiabetes.csv', RandomForestRegressor, space4rf, model_nm='rf', evals=20)
# Out:
# NODIABETES.CSV
# Target STD: 0.807
# Размер обучающей выборки: 585
# Размер тестовой выборки: 195
# 100%|████████████████████████████████████████████████| 20/20 [01:15<00:00,  3.79s/trial, best loss: 0.7956814578046705]
# 95% доверительный интервал модели для RMSE по кросс валидации: (0.730, 0.862)
# R2 test: 0.003, RMSE test: 0.805
# Clarke Error Grid: A - 152(77.95%), B - 41(21.03%), C - 0(0.0%), D - 2(1.03%), E - 0(0.0%)

# %% [markdown]
# ## Выборка после еды

# %%
build_asses_model('food.csv', XGBRegressor, xgboost_space)
# Out:
# FOOD.CSV
# Target STD: 3.499
# Размер обучающей выборки: 1599
# Размер тестовой выборки: 533
# 100%|█████████████████████████████████████████████████| 50/50 [00:21<00:00,  2.27trial/s, best loss: 3.263691441473976]
# 95% доверительный интервал модели для RMSE по кросс валидации: (2.996, 3.531)
# R2 test: 0.145, RMSE test: 3.215
# Clarke Error Grid: A - 208(39.02%), B - 279(52.35%), C - 0(0.0%), D - 45(8.44%), E - 1(0.19%)

# %%
build_asses_model('food.csv', RandomForestRegressor, space4rf, model_nm='rf', evals=20)
# Out:
# FOOD.CSV
# Target STD: 3.499
# Размер обучающей выборки: 1599
# Размер тестовой выборки: 533
# 100%|████████████████████████████████████████████████| 20/20 [03:19<00:00,  9.97s/trial, best loss: 3.2597751351641606]
# 95% доверительный интервал модели для RMSE по кросс валидации: (2.990, 3.524)
# R2 test: 0.153, RMSE test: 3.201
# Clarke Error Grid: A - 210(39.4%), B - 272(51.03%), C - 1(0.19%), D - 49(9.19%), E - 1(0.19%)

# %% [markdown]
# ## Выборка натощак

# %%
build_asses_model('fasting.csv', XGBRegressor, xgboost_space)
# Out:
# FASTING.CSV
# Target STD: 2.872
# Размер обучающей выборки: 461
# Размер тестовой выборки: 154
# 100%|█████████████████████████████████████████████████| 50/50 [00:12<00:00,  3.93trial/s, best loss: 2.672281895596365]
# 95% доверительный интервал модели для RMSE по кросс валидации: (1.990, 3.355)
# R2 test: 0.061, RMSE test: 3.064
# Clarke Error Grid: A - 57(37.01%), B - 88(57.14%), C - 0(0.0%), D - 9(5.84%), E - 0(0.0%)

# %%
build_asses_model('fasting.csv', RandomForestRegressor, space4rf, model_nm='rf', evals=20)
# Out:
# FASTING.CSV
# Target STD: 2.872
# Размер обучающей выборки: 461
# Размер тестовой выборки: 154
# 100%|████████████████████████████████████████████████| 20/20 [01:08<00:00,  3.44s/trial, best loss: 2.6550087099725697]
# 95% доверительный интервал модели для RMSE по кросс валидации: (1.975, 3.319)
# R2 test: 0.051, RMSE test: 3.080
# Clarke Error Grid: A - 49(31.82%), B - 95(61.69%), C - 0(0.0%), D - 10(6.49%), E - 0(0.0%)

# %% [markdown]
# ## Выборка ГКБ

# %%
build_asses_model('gkb.csv', XGBRegressor, xgboost_space)
# Out:
# GKB.CSV
# Target STD: 3.503
# Размер обучающей выборки: 1017
# Размер тестовой выборки: 339
# 100%|█████████████████████████████████████████████████| 50/50 [00:19<00:00,  2.58trial/s, best loss: 3.264281621540131]
# 95% доверительный интервал модели для RMSE по кросс валидации: (2.798, 3.731)
# R2 test: 0.128, RMSE test: 3.152
# Clarke Error Grid: A - 140(41.3%), B - 175(51.62%), C - 0(0.0%), D - 24(7.08%), E - 0(0.0%)

# %%
build_asses_model('gkb.csv', RandomForestRegressor, space4rf, model_nm='rf', evals=20)
# Out:
# GKB.CSV
# Target STD: 3.503
# Размер обучающей выборки: 1017
# Размер тестовой выборки: 339
# 100%|████████████████████████████████████████████████| 20/20 [01:42<00:00,  5.15s/trial, best loss: 3.2532017438209566]
# 95% доверительный интервал модели для RMSE по кросс валидации: (2.814, 3.696)
# R2 test: 0.132, RMSE test: 3.144
# Clarke Error Grid: A - 135(39.82%), B - 186(54.87%), C - 0(0.0%), D - 18(5.31%), E - 0(0.0%)

# %% [markdown]
# ## Выборка МКНЦ

# %%
build_asses_model('mknc.csv', XGBRegressor, xgboost_space)
# Out:
# MKNC.CSV
# Target STD: 3.325
# Размер обучающей выборки: 911
# Размер тестовой выборки: 304
# 100%|█████████████████████████████████████████████████| 50/50 [00:15<00:00,  3.30trial/s, best loss: 3.087042816714912]
# 95% доверительный интервал модели для RMSE по кросс валидации: (2.561, 3.613)
# R2 test: 0.144, RMSE test: 3.155
# Clarke Error Grid: A - 109(35.86%), B - 176(57.89%), C - 0(0.0%), D - 19(6.25%), E - 0(0.0%)

# %%
build_asses_model('mknc.csv', RandomForestRegressor, space4rf, model_nm='rf', evals=20)
# Out:
# MKNC.CSV
# Target STD: 3.325
# Размер обучающей выборки: 911
# Размер тестовой выборки: 304
# 100%|████████████████████████████████████████████████| 20/20 [02:05<00:00,  6.26s/trial, best loss: 3.0770004170879863]
# 95% доверительный интервал модели для RMSE по кросс валидации: (2.587, 3.564)
# R2 test: 0.142, RMSE test: 3.159
# Clarke Error Grid: A - 109(35.86%), B - 172(56.58%), C - 0(0.0%), D - 23(7.57%), E - 0(0.0%)

# %% [markdown]
# ## Выборка поликлиники

# %%
build_asses_model('poly.csv', XGBRegressor, xgboost_space)
# Out:
# POLY.CSV
# Target STD: 0.884
# Размер обучающей выборки: 132
# Размер тестовой выборки: 44
# 100%|████████████████████████████████████████████████| 50/50 [00:10<00:00,  4.64trial/s, best loss: 0.8634140720502174]
# 95% доверительный интервал модели для RMSE по кросс валидации: (0.559, 1.167)
# R2 test: -0.141, RMSE test: 0.804
# Clarke Error Grid: A - 38(86.36%), B - 6(13.64%), C - 0(0.0%), D - 0(0.0%), E - 0(0.0%)

# %%
build_asses_model('poly.csv', RandomForestRegressor, space4rf, model_nm='rf', evals=20)
# Out:
# POLY.CSV
# Target STD: 0.884
# Размер обучающей выборки: 132
# Размер тестовой выборки: 44
# 100%|████████████████████████████████████████████████| 20/20 [00:59<00:00,  2.98s/trial, best loss: 0.8665592070789707]
# 95% доверительный интервал модели для RMSE по кросс валидации: (0.500, 1.245)
# R2 test: -0.020, RMSE test: 0.761
# Clarke Error Grid: A - 39(88.64%), B - 5(11.36%), C - 0(0.0%), D - 0(0.0%), E - 0(0.0%)
